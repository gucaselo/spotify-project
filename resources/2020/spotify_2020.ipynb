# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint
from matplotlib import figure
import glob


final_data_file = r'C:\Users\robma\homework\spotify-project\output_data\Spotify_2020.csv'
# stack overflow ftw
csv_list = glob.glob('**/resources/2020/*.csv', recursive=True)
print(csv_list)
# Out:
# []

# %%
dataframes = []

# df_names
for name in csv_list:
        dataframes.append(pd.read_csv(name, header=1, encoding = 'UTF-8'))
# set dataframe variables
apr1 = dataframes[0]
apr2 = dataframes[1]
apr3 = dataframes[2]
apr4 = dataframes[3]
apr5 = dataframes[4]
aug1 = dataframes[5]
aug2 = dataframes[6]
aug3 = dataframes[7]
aug4 = dataframes[8]
dec1 = dataframes[9]
dec2 = dataframes[10]
dec3 = dataframes[11]
dec4 = dataframes[12]
feb1 = dataframes[13]
feb2 = dataframes[14]
feb3 = dataframes[15]
feb4 = dataframes[16]
jan1 = dataframes[17]
jan2 = dataframes[18]
jan3 = dataframes[19]
jan4 = dataframes[20]
jan5 = dataframes[21]
jul1 = dataframes[22]
jul2 = dataframes[23]
jul3 = dataframes[24]
jul4 = dataframes[25]
jul5 = dataframes[26]
jun1 = dataframes[27]
jun2 = dataframes[28]
jun3 = dataframes[29]
jun4 = dataframes[30]
mar1 = dataframes[31]
mar2 = dataframes[32]
mar3 = dataframes[33]
mar4 = dataframes[34]
may1 = dataframes[35]
may2 = dataframes[36]
may3 = dataframes[37]
may4 = dataframes[38]
nov1 = dataframes[39]
nov2 = dataframes[40]
nov3 = dataframes[41]
nov4 = dataframes[42]
oct1 = dataframes[43]
oct2 = dataframes[44]
oct3 = dataframes[45]
oct4 = dataframes[46]
oct5 = dataframes[47]
sep1 = dataframes[48]
sep2 = dataframes[49]
sep3 = dataframes[50]
sep4 = dataframes[51]

# create 'Week' column in dataframes
# april
apr1['Week'] = '1'
apr2['Week'] = '2'
apr3['Week'] = '3'
apr4['Week'] = '4'
apr5['Week'] = '5'
# august
aug1['Week'] = '1'
aug2['Week'] = '2'
aug3['Week'] = '3'
aug4['Week'] = '4'
# december
dec1['Week'] = '1'
dec2['Week'] = '2'
dec3['Week'] = '3'
dec4['Week'] = '4'
# february
feb1['Week'] = '1'
feb2['Week'] = '2'
feb3['Week'] = '3'
feb4['Week'] = '4'
# january - 5 weeks
jan1['Week'] = '1'
jan2['Week'] = '2'
jan3['Week'] = '3'
jan4['Week'] = '4'
jan5['Week'] = '5'
# july - 5 weeks
jul1['Week'] = '1'
jul2['Week'] = '2'
jul3['Week'] = '3'
jul4['Week'] = '4'
jul5['Week'] = '5'
# june
jun1['Week'] = '1'
jun2['Week'] = '2'
jun3['Week'] = '3'
jun4['Week'] = '4'
# march
mar1['Week'] = '1'
mar2['Week'] = '2'
mar3['Week'] = '3'
mar4['Week'] = '4'
# may - 5 weeks
may1['Week'] = '1'
may2['Week'] = '2'
may3['Week'] = '3'
may4['Week'] = '4'
# november
nov1['Week'] = '1'
nov2['Week'] = '2'
nov3['Week'] = '3'
nov4['Week'] = '4'
# october
oct1['Week'] = '1'
oct2['Week'] = '2'
oct3['Week'] = '3'
oct4['Week'] = '4'
oct5['Week'] = '5'
# september
sep1['Week'] = '1'
sep2['Week'] = '2'
sep3['Week'] = '3'
sep4['Week'] = '4'
sep4
# set monthly data frames
# january
january = [jan1,jan2,jan3,jan4,jan5]
january_df = pd.concat(january)
january_df['Month'] = 'January'
# january_df.to_csv(january_data)
# february
february = [feb1,feb2,feb3,feb4]
february_df = pd.concat(february)
february_df['Month'] = 'February'
# february_df.to_csv(february_data)
# march
march = [mar1,mar2,mar3,mar4]
march_df = pd.concat(march)
march_df['Month'] = 'March'
# march_df.to_csv(march_data)
# april
april = [apr1,apr2,apr3,apr4,apr5]
april_df = pd.concat(april)
april_df['Month'] = 'April'
# april_df.to_csv(april_data)
# may
may = [may1,may2,may3,may4]
may_df = pd.concat(may)
may_df['Month'] = 'May'
# may_df.to_csv(may_data)
# june
june = [jun1,jun2,jun3,jun4]
june_df = pd.concat(june)
june_df['Month'] = 'June'
# june_df.to_csv(june_data)
# july
july = [jul1,jul2,jul3,jul4,jul5]
july_df = pd.concat(july)
july_df['Month'] = 'July'
# july_df.to_csv(july_data)
# august
august = [aug1,aug2,aug3,aug4]
august_df = pd.concat(august)
august_df['Month'] = 'August'
# august_df.to_csv(august_data)
# september
september = [sep1,sep2,sep3,sep4]
september_df = pd.concat(september)
september_df['Month'] = 'September'
# september_df.to_csv(september_data)
# october
october = [oct1,oct2,oct3,oct4,oct5]
october_df = pd.concat(october)
october_df['Month'] = 'October'
# october_df.to_csv(october_data)
# november
november = [nov1,nov2,nov3,nov4]
november_df = pd.concat(november)
november_df['Month'] = 'November'
# november_df.to_csv(november_data)
# december
december = [dec1,dec2,dec3,dec4]
december_df = pd.concat(december)
december_df['Month'] = 'December'
# december_df.to_csv(december_data)
december_df
# set up yearly dataframe
months = [january_df, february_df, march_df, april_df, may_df, june_df, july_df, august_df, september_df,
         october_df, november_df, december_df]
year = pd.concat(months)
year
spotify2020_df = year.loc[:,['Position','Track Name', 'Artist', 'Streams', 'Week', 'Month']]
spotify2020_df['Year'] = '2020'
#spotify2020_df
# export csv
spotify2020_df.to_csv(final_data_file, encoding = 'utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-ff4c93ec7ee8> in <module>
#       5         dataframes.append(pd.read_csv(name, header=1, encoding = 'UTF-8'))
#       6 # set dataframe variables
# ----> 7 apr1 = dataframes[0]
#       8 apr2 = dataframes[1]
#       9 apr3 = dataframes[2]
#
# IndexError: list index out of range
